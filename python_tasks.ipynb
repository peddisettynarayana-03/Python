# %% [markdown]
# # Python Tasks

# %% [markdown]
# ## A. Python is an indent based programming language
# The following program throws an indentation error. Correct it and make sure it prints properly.
# teams = ['Data', 'AI', 'DevOps']
# for t in teams:
# print('Hello', t, 'Team from Inceptez Technologies')
#   print('Keep Learning and Exploring!')

# %%
from xml.dom.minidom import NamedNodeMap

teams = ['Data', 'AI', 'DevOps']
for t in teams:
    print('Hello', t, 'Team from Inceptez Technologies')
    print('Keep Learning and Exploring!')
# Out:
# Hello Data Team from Inceptez Technologies
# Keep Learning and Exploring!
# Hello AI Team from Inceptez Technologies
# Keep Learning and Exploring!
# Hello DevOps Team from Inceptez Technologies
# Keep Learning and Exploring!

# %% [markdown]
# ### B. Commented line in Python
# Use Case 1:
# Add single-line and multi-line comments to describe what the below code does for Inceptez Technologies’ training tracker.
#
# students = 100
# trainers = 2
# total = students + trainers
# print(total)

# %%
#No.of students
'''total students=100
and tariners=2'''
students = 100
trainers = 2
total = students + trainers
print(total)
# Out:
# 102

# %% [markdown]
# Use Case 2:
# Convert the below block into a “dead code” using comments, then re-activate it later to print
#
# print("Welcome to Inceptez Python Learning")

# %%
print("Welcome to Inceptez Python Learning")
# Out:
# Welcome to Inceptez Python Learning

# %% [markdown]
# ###  C. Playing with Quotes
# Use Case 1:
# Create three string variables that correctly store and print:
#
# This is Inceptez's "Python" class for Data Engineers & AI Engineers
# → Use single, double, and triple quotes appropriately.

# %%
print('''This is Inceptez's "Python" class for Data Engineers & AI Engineers''')
# Out:
# This is Inceptez's "Python" class for Data Engineers & AI Engineers

# %% [markdown]
# ###  Use Case 2:
# Write a multiline string using triple quotes that prints:
#
# Welcome to Inceptez Technologies!
# Python Training: Basics
# Enjoy your learning journey.

# %%
print('''Welcome to Inceptez Technologies!
Python Training: Basics
Enjoy your learning journey.''')
# Out:
# Welcome to Inceptez Technologies!
# Python Training: Basics
# Enjoy your learning journey.

# %% [markdown]
# ### D. Let's learn all about VARIABLES
# Use Case 1:
# Declare variables to store the following details:
# - Student Name
# - Course Name (e.g., “Python Fundamentals”)
# - Training Institute Name (Inceptez Technologies)
#
# Then print a formatted message:
#
# Name: Narayana is learning the course Python Fundamentals at the institute Inceptez Technologies

# %%
Student_Name='Narayana'
Course_Name='Python Fundamentals'
Training_Institide='Inceptez Technologies'
print(Student_Name,"is learning the course",Course_Name,"at the institute",Training_Institide)
# Out:
# Nani is learning the course Python Fundamentals at the institute Inceptez Technologies

# %% [markdown]
# ##  Use Case 2:
# Demonstrate dynamic inference, dynamic typing using with fee by applying .18 gst  and prove strongly typing character also by operating it with Eighteen percent gst
#
# fee = 45000

# %%
#dynamic interference
fee="4500"
type(fee)
#dynamically typed
number= 10
type(number)

##strongly typed- it doesn't convert the types
fee=4500
gst='18%'
total=fee+gst

# %% [markdown]
# ##  E. Variables Naming Conventions
# Use Case 1:
# Identify which variable names below are invalid for Inceptez’s student database:
#
# 1) 2student = 'Ravi'
# 2) _student_id = 1001
# 3) studentName = 'Priya'
# 4) class name = 'Python'
# 5) inceptez_batch = 'Morning'

# %%
2student= 'Ravi' #invalid not start with numbers
_student_id= 1001 #valid
studentName = 'Priya' #valid
class name = 'Python' #invalid
inceptez_batch = 'Morning' #valid

# %%
inceptez_batch  = 'Python'
print(inceptez_batch    )
# Out:
# Python

# %% [markdown]
# Use Case 2:
# Declare 3 variables following naming styles for Inceptez projects:
#
# PascalCase: DataEngineeringBatch
# camelCase: dataEngineeringBatch
# snake_case: data_engineering_batch

# %%
print("DataEngineeringBatch") #PASCAL CASE
print("dataEngineeringBatch") #CAMEL CASE
print("data_engineering_batch") #SNAKE CASE
# Out:
# DataEngineeringBatch
# dataEngineeringBatch
# data_engineering_batch

# %% [markdown]
# ##F. Type identification & Casting
# Use Case 1:
# Sample code: As we didn’t covered this function input() yet in our session, I am giving the below sample code for your reference.
# Write a program that asks for an employee’s age.
# age=input("Enter employee's age")

# %%
age=int(input("Enter your age:"))
if age>40:
    print("You will retire in 20 years at inceptez Technologies")
else:
    print("welcome to incepetez")
# Out:
# You will retire in 20 years at inceptez Technologies

# %% [markdown]
# Use Case 2 (Debug):
# Fix the type error in the following code for salary calculation:
#
# salary = '50000'
# bonus = 10000
# print('Total Salary in Inceptez:', salary + bonus)

# %%
salary = '50000'
bonus = 10000
print('Total Salary in Inceptez:', int(salary) + bonus)
# Out:
# Total Salary in Inceptez: 60000

# %% [markdown]
# G. Data types and casting
# Use Case 1 — Employee Salary Breakdown Using Numeric & String Types
# Employee Salary Breakdown
# a. Write a program that asks the user for:
# employee_name (string)
# base_salary (float)
# hra_percent (integer)
# bonus_amount (float)

# %%
employee_name=str(input("Enter your name"))
base_salary=float(input("Enter your salary"))
hra_percentage=int(input("Enter your hra percentage"))
bonus_amount=float(input("Enter your bonus amount"))

print("Employee is ",employee_name,"his base salary is",base_salary, "and his hra percentage is",hra_percentage,"with bonus amount is",bonus_amount)

hra = base_salary * (hra_percentage / 100)
print(hra)

total_salary = base_salary + hra + bonus_amount

print(total_salary)
# Out:
# Employee is  Narayana
#  his base salary is 10.5 and his hra percentage is 95 with bonus amount is 3.5
# 23.975

# %% [markdown]
# B. Convert inputs to the correct datatype if required.
# Calculate:
#  HRA = base_salary * (hra_percent / 100)
#  Total Salary = base_salary + HRA + bonus_amount

# %%
employee_name=str(input("Enter your name"))
base_salary=float(input("Enter your salary"))
hra_percentage=int(input("Enter your hra percentage"))
bonus_amount=float(input("Enter your bonus amount"))

print("Employee is ",employee_name,"his base salary is",base_salary, "and his hra percentage is",hra_percentage,"with bonus amount is",bonus_amount)

hra = base_salary * (hra_percentage / 100)
print(hra)

total_salary = base_salary + hra + bonus_amount

print(total_salary)

# %% [markdown]
# ### C. Print the output like this:
# Employee: Arun
# Base Salary: 40000.0
# HRA @ 20%: 8000.0
# Bonus: 5000.0
# Total Salary Payable: ₹53000.0

# %%
employee_name=str(input("Enter your name in numbers"))
base_salary=float(input("Enter your salary in decimal"))
hra_percentage=int(input("Enter your hra percentage in numbers"))
bonus_amount=float(input("Enter your bonus amount in decimal"))

print("Employee is ",employee_name,"his base salary is",base_salary, "and his hra percentage is",hra_percentage,"with bonus amount is",bonus_amount)

hra = base_salary * (hra_percentage / 100)
print(hra)

total_salary = base_salary + hra + bonus_amount

print(total_salary)

print("Employee:",employee_name)
print("Base Salary:",base_salary)
print("HRA @20%:",hra_percentage)
print("Bonus:",bonus_amount)
print("Total Salary Payable:",total_salary)
# Out:
# Employee is  Narayana his base salary is 10.5 and his hra percentage is 95 with bonus amount is 3.5
# 9.975
# 23.975
# Employee: Narayana
# Base Salary: 10.5
# HRA @20%: 95
# Bonus: 3.5
# Total Salary Payable: 23.975

# %% [markdown]
# Use Case 2: Student Result Classification
# a. Write a program that takes marks as input (initially as a string).

# %%
marks = str(input("Enter your marks: "))

try:
    marks = float(marks)
    print("Valid marks:", marks)
except ValueError:
    print("Marks cannot be converted to float")
# Out:
# Valid marks: 56.0

# %% [markdown]
# ##  C. Then classify (try using if condition with the help of AI, however we will learn about if condition soon):

# %%
marks=(input("Enter your marks: "))
print(marks)
try:
    marks=float(marks)
    if marks>=90:
        print("outstanding")
    elif marks>=75:
        print("Excellent")
    elif marks>=50:
        print("Pass")
    else:
        print("Fail")

except ValueError:
    print("Invalid Marks Entered - Please provide numberic input")
# Out:
# 98
# outstanding

# %% [markdown]
# ## Use Case 3: Bug Fixing — Datatype Mismatch
# The below code is intended to calculate total price, but it has datatype errors. Fix it.
# Incorrect code:
# item_name = input("Enter product name: ")
#  price = input("Enter price per item: ")
#  quantity = input("Enter quantity: ")
# total_cost = price * quantity
# print("You purchased " + quantity + " units of " + item_name)
#  print("Total payable: " + total_cost)
# Expected output after fixing:
# Enter product name: Notepad
#  Enter price per item: 35.50
#  Enter quantity: 3
# You purchased 3 units of Notepad
#  Total payable: 106.5 INR

# %%
item_name = str(input("Enter product name: "))
price = float(input("Enter price per item: "))
quantity = int(input("Enter quantity: "))
total_cost = price * quantity
print("Enter Product Name:",item_name)
print("Enter Price per Item:",price)
print("Enter Quantity:",quantity)
print(f"You purchased  {quantity}   units of   {item_name}")
print(f"Total payable:  {total_cost}")
# Out:
# Enter Product Name: Notepad
# Enter Price per Item: 35.5
# Enter Quantity: 3
# You purchased  3   units of   Notepad
# Total payable:  106.5

# %% [markdown]
# ## H. Python Operators Usecases
# Use Case 1: Internet Data Usage Calculator
# Write a program that asks the user for:
# Total monthly data limit (in GB)
# Data used so far (in GB)
#
# Calculate using arithmetic operators:
#  Remaining data = limit - used
#  Usage percentage = (used / limit) * 100
# Print:
# Remaining data
# Usage percentage rounded to 2 decimals
#
# If usage percentage is greater than or equal to 80, print:
#  "Warning: High usage, consider upgrading your plan."

# %%
Total_monthly_data_limit = int(input("Enter Monthly data Limit"))
Date_used_so_far = int(input("Enter data used so far"))
print("Total_monthly_data_limit:",Total_monthly_data_limit)
print("Date_used_so_far:",Date_used_so_far)
Remaining_Data= Total_monthly_data_limit - Date_used_so_far
print("Remaining_Data:",Remaining_Data)
Usage_Percentage = (Date_used_so_far/Total_monthly_data_limit)*100
print(F"Usage_Percentage: {Usage_Percentage}%")
if Usage_Percentage>=80:
    print("Warning:High Usage, consider your plan.")
# Out:
# Total_monthly_data_limit: 500
# Date_used_so_far: 1000
# Remaining_Data: -500
# Usage_Percentage: 200.0%
# Warning:High Usage, consider your plan.

# %% [markdown]
# ### Use Case 2: Shopping Discount Calculation
# Write a program that takes:
# Original price (float)
# Discount percent (int)
#
#
# Using assignment and arithmetic operators, calculate:
#  Discount amount = (price * discount_percent) / 100
#  Final price = price - discount_amount
# Print:
#  Original price, discount applied, and final payable amount.

# %%
Original_price= float(input("Enter Price"))
Discount_percent = int(input("Enter Discount"))
print("Original_price:",Original_price)
print("Discount_percent:",Discount_percent)
Discount_amount= (Original_price * Discount_percent)/100
print("Discount_amount:",Discount_amount)
Final_price = Original_price - Discount_amount
print(f"Original price: {Original_price}, Discount_amount: {Discount_amount}, and final payable amount.{Final_price}")
# Out:
# Original_price: 100.0
# Discount_percent: 5
# Discount_amount: 5.0
# Original price: 100.0, Discount_amount: 5.0, and final payable amount.95.0

# %% [markdown]
# Use Case 3 (Bug Fixing): Logical and Comparison Operator Errors
# The following code should determine voting eligibility, but it contains operator mistakes. Fix it.
# Incorrect code:
# age = input("Enter age: ")
#  citizen = input("Are you an Indian citizen? (yes/no)")
# if age > "18" and citizen = "yes":
#  print("Eligible to vote")
#  else:
#  print("Not eligible")

# %%
age=int(input("Enter your age: "))
citizen=str(input("Enter your citizen: (Yes/No)"))
print(age,citizen)
if age>=18 and citizen.lower()=="yes":
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# 18 yes
#
# not eleigible

# %% [markdown]
# I. Conditional Structure
# Use Case 1: Banking Eligibility Check
# Write a program that asks the user for:
# Age
# Monthly income
#
#
# Conditions:
# If age < 18: print "Not eligible for a bank account."
# If age >= 18 and income < 15000: print "Eligible for basic savings account."
# If age >= 18 and income between 15000 and 50000: print "Eligible for savings + salary account."
# If age >= 18 and income > 50000: print "Eligible for premium account."

# %%
age = int(input("Enter your age: "))
Monthly_income= int(input("Enter Monthly income: "))
print(age,Monthly_income)
if age <18:
        print("Not Eligible for a Bank Account")
elif age >= 18 and Monthly_income<15000:
        print("Eligible for basic savings account")
elif age >= 18 and 15000 <= Monthly_income <= 50000:
        print("Eligible for savings + salary account")
else:
        print("Sorry, Not Eligible")
# Out:
# 24 50000
# Eligible for savings + salary account
